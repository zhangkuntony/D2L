# %% [markdown]
# ### 梯度消失

# %%
import torch
from d2l import d2l_torch as d2l

x = torch.arange(-8.0, 8.0, 1, requires_grad=True)
y = torch.sigmoid(x)
y.backward(torch.ones_like(y))

d2l.plot(x.detach().numpy(), [y.detach().numpy(), x.grad.numpy()],
         legend=['sigmoid', 'gradient'], figsize=(4.5, 2.5))

# %% [markdown]
# ### 梯度爆炸

# %%
M = torch.normal(0, 1, size=(4,4))
print('一个矩阵 \n', M)
for i in range(100):
    M = torch.mm(M, torch.normal(0, 1, size=(4,4)))

print('乘以100个矩阵后\n', M)
# Out:
# 一个矩阵
#  tensor([[-0.4986, -0.0230, -1.8308,  0.7422],
#         [-0.6214,  1.4423, -0.4041,  0.8318],
#         [-0.2390, -0.6892, -0.1803, -1.0653],
#         [ 1.0645,  0.1162,  0.6896, -0.4984]])
# 乘以100个矩阵后
#  tensor([[ 7.3154e+22,  3.6632e+23,  1.0886e+23,  3.7261e+22],
#         [-7.1233e+21, -3.5670e+22, -1.0601e+22, -3.6283e+21],
#         [-9.0768e+20, -4.5453e+21, -1.3508e+21, -4.6233e+20],
#         [-1.9876e+22, -9.9532e+22, -2.9579e+22, -1.0124e+22]])
